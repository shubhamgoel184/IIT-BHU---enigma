# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train_NIR5Yl1.csv')
print(train.shape)
train
# Out:
# (330045, 7)
#             ID Tag  Reputation  Answers  Username     Views  Upvotes
# 0        52664   a      3942.0      2.0    155623    7855.0     42.0
# 1       327662   a     26046.0     12.0     21781   55801.0   1175.0
# 2       468453   c      1358.0      4.0     56177    8067.0     60.0
# 3        96996   a       264.0      3.0    168793   27064.0      9.0
# 4       131465   c      4271.0      4.0    112223   13986.0     83.0
# 5       345568   r       440.0      1.0     23866    5577.0      4.0
# 6       376865   c       147.0      1.0     10759   17184.0     17.0
# 7       467378   j      2269.0      2.0     54623     312.0      3.0
# 8       393640   j       111.0      2.0    172926   53738.0     79.0
# 9       130054   c      2749.0      1.0     10189     227.0      0.0
# 10      218471   c      1142.0      7.0     71822  141836.0    166.0
# 11      144119   p      2554.0      1.0    137817    8086.0     42.0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330045 entries, 0 to 330044
# Data columns (total 7 columns):
# ID            330045 non-null int64
# Tag           330045 non-null object
# Reputation    330045 non-null float64
# Answers       330045 non-null float64
# Username      330045 non-null int64
# Views         330045 non-null float64
# Upvotes       330045 non-null float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 17.6+ MB

# %%
train['Reputation'].describe()
# Out:
# count    3.300450e+05
# mean     7.773147e+03
# std      2.706141e+04
# min      0.000000e+00
# 25%      2.820000e+02
# 50%      1.236000e+03
# 75%      5.118000e+03
# max      1.042428e+06
# Name: Reputation, dtype: float64

# %%
train['Reputation'].sort_values(ascending = False)
# Out:
# 160728    1042428.0
# 236399    1042428.0
# 263169    1042428.0
# 323830    1042428.0
# 163006    1042428.0
# 206130    1042428.0
# 74699      813374.0
# 70073      813364.0
# 134390     813314.0
# 64572      813314.0
# 111929     809973.0
# 159776     793888.0
# 320822     764616.0
# 261013     750042.0
# 4503       750042.0
# 4778       750042.0
# 117542     750042.0
# 184515     750042.0
# 237733     737382.0
# 55992      737382.0
# 160437     737382.0
# 307142     737382.0
# 269135     737382.0
# 78961      737382.0
# 301508     737382.0
# 54833      737382.0
# 139572     737382.0
# 237002     737382.0
# 1090       737382.0
# 328836     737382.0
#             ...
# 50821           0.0
# 50856           0.0
# 236803          0.0
# 253871          0.0
# 104156          0.0
# 184730          0.0
# 184451          0.0
# 184439          0.0
# 253888          0.0
# 116738          0.0
# 226141          0.0
# 184419          0.0
# 133059          0.0
# 226103          0.0
# ...

# %%
train['Reputation'].nunique()
# Out:
# 16527

# %%
train.loc[train['Reputation'] == 0]['Reputation'].count()
# Out:
# 6632

# %%
train['Username'].nunique()
# Out:
# 141802

# %%
train['ID'].nunique()
# Out:
# 330045

# %%
print(train['Tag'].nunique())
train['Tag'].unique()
# Out:
# 10
# array(['a', 'c', 'r', 'j', 'p', 's', 'h', 'o', 'i', 'x'], dtype=object)

# %%
train.columns
# Out:
# Index(['ID', 'Tag', 'Reputation', 'Answers', 'Username', 'Views', 'Upvotes'], dtype='object')

# %%
train['Reputation'].corr(train['Upvotes'])
# Out:
# 0.26671036451576557

# %%
train['Reputation'].corr(train['Answers'])
# Out:
# 0.066504298540791693

# %%
train['Reputation'].corr(train['Views'])
# Out:
# 0.036455470617429632

# %%
train['Answers'].corr(train['Upvotes'])
# Out:
# 0.20203316672026048

# %%
train['Answers'].corr(train['Views'])
# Out:
# 0.49864223433758936

# %%
train['Views'].corr(train['Upvotes'])
# Out:
# 0.43733557651542121

# %%
train.corr()
# Out:
#                   ID  Reputation   Answers  Username     Views   Upvotes
# ID          1.000000    0.008546  0.017448  0.000628  0.017400  0.006328
# Reputation  0.008546    1.000000  0.066504 -0.041019  0.036455  0.266710
# Answers     0.017448    0.066504  1.000000 -0.012197  0.498642  0.202033
# Username    0.000628   -0.041019 -0.012197  1.000000  0.002306 -0.011970
# Views       0.017400    0.036455  0.498642  0.002306  1.000000  0.437336
# Upvotes     0.006328    0.266710  0.202033 -0.011970  0.437336  1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (15,10)

# %%
plt.scatter(np.log(train['Answers'] + 1), train['Views'])
plt.show()

# %%
a = train.loc[train['Upvotes'] < 50000]

# %%
plt.scatter((train['Answers']), np.log(train['Upvotes']+1))
plt.show()

# %%
plt.scatter(a['Answers'].unique(), a.groupby('Answers')['Upvotes'].mean())
plt.show()

# %%
plt.scatter(train['Views'], train['Upvotes'])
plt.show()

# %%
train['Answers'].describe()
# Out:
# count    330045.000000
# mean          3.917672
# std           3.579515
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           5.000000
# max          76.000000
# Name: Answers, dtype: float64

# %%
train['Upvotes'].describe()
# Out:
# count    330045.000000
# mean        337.505358
# std        3592.441135
# min           0.000000
# 25%           8.000000
# 50%          28.000000
# 75%         107.000000
# max      615278.000000
# Name: Upvotes, dtype: float64

# %%
groupby_tag = train.groupby('Tag')
groupby_tag.count().sort_values('Upvotes')
# Out:
#         ID  Reputation  Answers  Username  Views  Upvotes
# Tag
# x     6978        6978     6978      6978   6978     6978
# r    12442       12442    12442     12442  12442    12442
# o    14546       14546    14546     14546  14546    14546
# h    20564       20564    20564     20564  20564    20564
# s    23323       23323    23323     23323  23323    23323
# a    31695       31695    31695     31695  31695    31695
# i    32400       32400    32400     32400  32400    32400
# p    43407       43407    43407     43407  43407    43407
# j    72232       72232    72232     72232  72232    72232
# c    72458       72458    72458     72458  72458    72458

# %%
groupby_tag.mean().sort_values('Upvotes')
# Out:
#                 ID    Reputation   Answers      Username         Views  \
# Tag
# r    236191.361839   5290.282109  2.304292  85050.551680  12033.055940
# o    236318.977863   5656.755603  3.380654  79516.507837  13504.645538
# i    220363.254846   5238.884290  3.679753  78998.210772  15806.680093
# x    237098.152909   6456.155345  2.768845  81995.143881  16119.253941
# s    232761.903915   6545.661622  3.600866  79245.883463  25807.082965
# a    239590.353494   6065.168102  4.259189  81496.349109  31800.916327
# c    237971.012863  10566.420657  4.047697  80334.959632  26746.676875
# h    236766.817788   6985.072116  3.778837  81933.633291  33948.958812
# p    237951.321515   8062.053033  3.977077  84852.298869  33184.984334
# j    237764.331930   8285.527730  4.347256  81861.391115  43291.211236
#
#         Upvotes
# Tag
# r     79.027246
# o    112.157294
# i    117.386636
# x    151.255231
# s    237.031385
# a    316.460136
# c    327.569916
# h    384.719704
# p    407.351971
# ...

# %%
groupby_tag.median().sort_values('Upvotes')
# Out:
#            ID  Reputation  Answers  Username    Views  Upvotes
# Tag
# r    236425.0       702.0      2.0   82225.0   2865.0     11.0
# x    236870.0       901.5      2.0   79642.5   5027.0     13.0
# s    229399.0       895.0      3.0   75014.0   5721.0     16.0
# o    236986.0      1464.0      3.0   78001.0   5033.0     17.0
# h    236767.5       984.0      3.0   79375.5   8111.0     20.0
# i    209093.5      1243.0      3.0   76728.0   6246.5     20.0
# p    239075.0      1120.0      3.0   84019.0  10382.0     30.0
# c    239311.5      1629.5      3.0   77063.5   8405.0     33.0
# a    241846.0      1098.0      3.0   79096.0  12822.0     35.0
# j    239113.5      1376.0      3.0   79638.0  14471.0     42.0

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
kfold = KFold(n_splits= 5, shuffle = True)
X = train[['Answers', 'Views', 'Reputation']]
Y = train['Upvotes']
lr = LinearRegression(normalize=True)
for train_index, test_index in kfold.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]
    lr.fit(X_train, Y_train)
    y_pred = lr.predict(X_test)
    print(sqrt(mean_squared_error(Y_test, y_pred)))
    print(lr.coef_)
    print(lr.score(X_test, Y_test))
# Out:
# 2565.075201085897
# [ -3.92083641e+01   2.04183468e-02   3.45977338e-02]
# 0.250334212712
# 3316.0657656348412
# [ -4.04352970e+01   1.95005188e-02   3.29728664e-02]
# 0.274744372773
# 2775.8257977914004
# [ -3.03441857e+01   1.91722830e-02   3.39199465e-02]
# 0.326253127707
# 3565.296164154424
# [ -3.55356785e+01   1.96267223e-02   3.25722864e-02]
# 0.225720701233
# 3184.8975204198787
# [ -4.29949608e+01   2.03821673e-02   3.38192917e-02]
# 0.203451321778

# %%
ridgecv = RidgeCV(alphas=(0.002, 0.0025, 0.0027, 0.0028, 0.00295, 0.003, 0.00305, 0.0032, 0.0035), normalize=True)
ridgecv.fit(train[['Answers', 'Views', 'Reputation']], train['Upvotes'])
ridgecv.alpha_
# Out:
# 0.0030500000000000002

# %%
from sklearn.linear_model import Ridge
from sklearn.svm import SVR

# %%
kfold = KFold(n_splits= 5, shuffle = True)
X = train[['Answers', 'Views', 'Reputation']]
Y = train['Upvotes']
ridge = Ridge(alpha=0.00305, normalize= True)
for train_index, test_index in kfold.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]
    ridge.fit(X_train, Y_train)
    y_pred = ridge.predict(X_test)
    print(sqrt(mean_squared_error(Y_test, y_pred)))
    print(ridge.score(X_test, Y_test))
# Out:
# 3262.2689076096995
# 0.26608080903
# 3815.1490285029886
# 0.209181607799
# 2844.0768473350545
# 0.217771417782
# 2391.9233079158084
# 0.282463541348
# 3033.9283203884484
# 0.308280760363

# %%
test = pd.read_csv('test_8i3B3FC.csv')
test
# Out:
#             ID Tag  Reputation  Answers  Username     Views
# 0       366953   a      5645.0      3.0     50652   33200.0
# 1        71864   c     24511.0      6.0     37685    2730.0
# 2       141692   i       927.0      1.0    135293   21167.0
# 3       316833   i        21.0      6.0    166998   18528.0
# 4       440445   i      4475.0     10.0     53504   57240.0
# 5         3514   c      3252.0      1.0    115109    2307.0
# 6       331420   x       859.0      1.0     88355    6507.0
# 7       406540   c       770.0      4.0     74489   57775.0
# 8       227379   s      8727.0      2.0     37904    4459.0
# 9       331687   p       170.0      4.0    162810    4899.0
# 10       32784   p        58.0      2.0    156743    1251.0
# 11      470377   s       727.0      2.0      1960   27814.0
# 12      338103   o      1295.0      3.0     67702    2827.0
# 13       29883   p      1231.0      7.0    154204  162617.0
# 14      218228   c       205.0      8.0    142854   36677.0
# ...

# %%
ridge.fit(X, Y)
y_pred = ridge.predict(test[['Answers', 'Views', 'Reputation']])
ridge.coef_
# Out:
# array([ -3.66497980e+01,   1.97466694e-02,   3.34729259e-02])

# %%
test['Upvotes'] = y_pred
ridge = test.sort_values('ID')
ridge
# Out:
#             ID Tag  Reputation  Answers  Username     Views       Upvotes
# 118045       7   h      2552.0     16.0    114390  284348.0   4749.457930
# 74256        9   j      1240.0      2.0     59362    6587.0   -266.216006
# 132030      12   p       560.0      6.0     44764   37074.0    166.439921
# 47484       13   j     16807.0      3.0     25037   17598.0    435.637810
# 20847       16   i       896.0      4.0    134342   16800.0   -149.357555
# 140788      17   x     67157.0     10.0    100794   85709.0   3209.416443
# 17680       22   c       103.0      1.0     35973     464.0   -388.533782
# 28140       25   j       602.0      6.0     26545   26047.0    -49.900739
# 55781       26   c       107.0      4.0     41953   13714.0   -236.705915
# 96215       27   j      1117.0      3.0     98395   37627.0    305.953643
# 93870       33   p      1647.0      6.0     54659   13065.0   -271.272793
# 391         43   i      4988.0      2.0     30272    2446.0   -222.530438
# ...

# %%
ridge[['ID', 'Upvotes']].to_csv('ridge.csv')

# %%
lr.fit(X, Y)
y_pred = lr.predict(test[['Answers', 'Views', 'Reputation']])
test['Upvotes'] = y_pred
lr = test.sort_values('ID')
lr
# Out:
#             ID Tag  Reputation  Answers  Username     Views       Upvotes
# 118045       7   h      2552.0     16.0    114390  284348.0   4756.812040
# 74256        9   j      1240.0      2.0     59362    6587.0   -266.692846
# 132030      12   p       560.0      6.0     44764   37074.0    164.021603
# 47484       13   j     16807.0      3.0     25037   17598.0    436.574221
# 20847       16   i       896.0      4.0    134342   16800.0   -151.224524
# 140788      17   x     67157.0     10.0    100794   85709.0   3213.478131
# 17680       22   c       103.0      1.0     35973     464.0   -388.534665
# 28140       25   j       602.0      6.0     26545   26047.0    -53.233158
# 55781       26   c       107.0      4.0     41953   13714.0   -238.910948
# 96215       27   j      1117.0      3.0     98395   37627.0    306.946716
# 93870       33   p      1647.0      6.0     54659   13065.0   -275.579123
# 391         43   i      4988.0      2.0     30272    2446.0   -222.967218
# ...

# %%
lr[['ID', 'Upvotes']].to_csv('linear.csv')

# %%
tag_wt_dict = groupby_tag['Upvotes'].mean().to_dict()
tag_wt_dict_med = groupby_tag['Upvotes'].median().to_dict()
tag_wt_dict
# Out:
# {'a': 316.46013566808642,
#  'c': 327.56991636534269,
#  'h': 384.71970433767751,
#  'i': 117.38663580246913,
#  'j': 540.36468601173999,
#  'o': 112.15729410147119,
#  'p': 407.35197088027275,
#  'r': 79.027246423404591,
#  's': 237.03138532778803,
#  'x': 151.25523072513613}

# %%
train['mean_wt_tag'] = train['Tag'].apply(lambda x: tag_wt_dict[x])
train['median_wt_tag'] = train['Tag'].apply(lambda x: tag_wt_dict_med[x])
train
# Out:
#             ID Tag  Reputation  Answers  Username     Views  Upvotes  \
# 0        52664   a      3942.0      2.0    155623    7855.0     42.0
# 1       327662   a     26046.0     12.0     21781   55801.0   1175.0
# 2       468453   c      1358.0      4.0     56177    8067.0     60.0
# 3        96996   a       264.0      3.0    168793   27064.0      9.0
# 4       131465   c      4271.0      4.0    112223   13986.0     83.0
# 5       345568   r       440.0      1.0     23866    5577.0      4.0
# 6       376865   c       147.0      1.0     10759   17184.0     17.0
# 7       467378   j      2269.0      2.0     54623     312.0      3.0
# 8       393640   j       111.0      2.0    172926   53738.0     79.0
# 9       130054   c      2749.0      1.0     10189     227.0      0.0
# 10      218471   c      1142.0      7.0     71822  141836.0    166.0
# 11      144119   p      2554.0      1.0    137817    8086.0     42.0
# 12      155955   s       591.0      4.0     36550   16102.0     19.0
# ...

# %%
test['mean_wt_tag'] = test['Tag'].apply(lambda x: tag_wt_dict[x])
test['median_wt_tag'] = test['Tag'].apply(lambda x: tag_wt_dict_med[x])
test
# Out:
#             ID Tag  Reputation  Answers  Username     Views       Upvotes  \
# 0       366953   a      5645.0      3.0     50652   33200.0     27.699515
# 1        71864   c     24511.0      6.0     37685    2730.0     57.141094
# 2       141692   i       927.0      1.0    135293   21167.0     13.295311
# 3       316833   i        21.0      6.0    166998   18528.0     27.183856
# 4       440445   i      4475.0     10.0     53504   57240.0     70.338111
# 5         3514   c      3252.0      1.0    115109    2307.0     15.898558
# 6       331420   x       859.0      1.0     88355    6507.0     12.492342
# 7       406540   c       770.0      4.0     74489   57775.0     33.848225
# 8       227379   s      8727.0      2.0     37904    4459.0     19.442912
# 9       331687   p       170.0      4.0    162810    4899.0     25.770578
# 10       32784   p        58.0      2.0    156743    1251.0     18.576101
# 11      470377   s       727.0      2.0      1960   27814.0     18.540640
# ...

# %%
lr = LinearRegression(normalize=True)
lr.fit(train[['Reputation', 'Answers', 'Views', 'mean_wt_tag']], train['Upvotes'])
y_pred = lr.predict(test[['Reputation', 'Answers', 'Views', 'mean_wt_tag']])
test['Upvotes'] = y_pred
lr_with_tag = test.sort_values('ID')
lr_with_tag
# Out:
#             ID Tag  Reputation  Answers  Username     Views       Upvotes  \
# 118045       7   h      2552.0     16.0    114390  284348.0   4764.705551
# 74256        9   j      1240.0      2.0     59362    6587.0   -357.904222
# 132030      12   p       560.0      6.0     44764   37074.0    135.868063
# 47484       13   j     16807.0      3.0     25037   17598.0    348.024251
# 20847       16   i       896.0      4.0    134342   16800.0    -57.573838
# 140788      17   x     67157.0     10.0    100794   85709.0   3306.967671
# 17680       22   c       103.0      1.0     35973     464.0   -389.415970
# 28140       25   j       602.0      6.0     26545   26047.0   -139.486236
# 55781       26   c       107.0      4.0     41953   13714.0   -236.135423
# 96215       27   j      1117.0      3.0     98395   37627.0    218.778213
# 93870       33   p      1647.0      6.0     54659   13065.0   -305.315565
# 391         43   i      4988.0      2.0     30272    2446.0   -131.874174
# ...

# %%
lr_with_tag[['ID', 'Upvotes']].to_csv('lr_with_tag.csv')

# %%
ridgecv = RidgeCV(alphas=(0.002, 0.0025, 0.0027, 0.0028, 0.00295, 0.00304, 0.00303, 0.00302, 0.0035), normalize=True)
ridgecv.fit(train[['Answers', 'Views', 'Reputation', 'mean_wt_tag']], train['Upvotes'])
ridgecv.alpha_
# Out:
# 0.0030200000000000001

# %%
ridge = Ridge(alpha=0.00303, normalize= True)
ridge.fit(train[['Answers', 'Views', 'Reputation', 'mean_wt_tag']], train['Upvotes'])
y_pred = ridge.predict(test[['Answers', 'Views', 'Reputation', 'mean_wt_tag']])
test['Upvotes'] = y_pred
ridge_with_tag = test.sort_values('ID')
ridge_with_tag
# Out:
#             ID Tag  Reputation  Answers  Username     Views       Upvotes  \
# 118045       7   h      2552.0     16.0    114390  284348.0   4757.258098
# 74256        9   j      1240.0      2.0     59362    6587.0   -356.413991
# 132030      12   p       560.0      6.0     44764   37074.0    138.581162
# 47484       13   j     16807.0      3.0     25037   17598.0    348.075847
# 20847       16   i       896.0      4.0    134342   16800.0    -56.752593
# 140788      17   x     67157.0     10.0    100794   85709.0   3301.873818
# 17680       22   c       103.0      1.0     35973     464.0   -389.397095
# 28140       25   j       602.0      6.0     26545   26047.0   -135.219471
# 55781       26   c       107.0      4.0     41953   13714.0   -233.971224
# 96215       27   j      1117.0      3.0     98395   37627.0    218.767989
# 93870       33   p      1647.0      6.0     54659   13065.0   -300.704785
# 391         43   i      4988.0      2.0     30272    2446.0   -132.442436
# ...

# %%
ridge_with_tag[['ID', 'Upvotes']].to_csv('ridge_with_tag.csv')

# %%
mean_ans_dict = train.groupby('Answers')['Upvotes'].mean().to_dict()
mean_ans_dict
# Out:
# {0.0: 32.905859750240154,
#  1.0: 51.898600325362963,
#  2.0: 94.287509259388671,
#  3.0: 136.81823507482559,
#  4.0: 217.85285908361121,
#  5.0: 325.37756090560083,
#  6.0: 408.97185571398171,
#  7.0: 567.40150197628464,
#  8.0: 676.44741552920118,
#  9.0: 852.01921229586935,
#  10.0: 1145.4677025527192,
#  11.0: 1317.8737105345419,
#  12.0: 1265.2392712550607,
#  13.0: 1699.2750000000001,
#  14.0: 1871.0388479571334,
#  15.0: 2497.7728459530026,
#  16.0: 2604.3428246013668,
#  17.0: 2834.9915611814345,
#  18.0: 3537.1967799642216,
#  19.0: 4195.8175965665232,
#  20.0: 6384.0911330049257,
#  21.0: 6972.7040816326535,
#  22.0: 3762.0959409594097,
#  23.0: 3918.3244444444445,
#  24.0: 7610.7416267942581,
#  25.0: 4122.6585365853662,
#  26.0: 8922.8709677419356,
#  27.0: 3624.463917525773,
#  28.0: 3511.0952380952381,
#  29.0: 13060.946236559139,
#  30.0: 5023.7799999999997,
#  31.0: 8790.3690476190477,
#  32.0: 21020.607142857141,
#  33.0: 2691.5714285714284,
# ...

# %%
median_ans_dict = train.groupby('Answers')['Upvotes'].median().to_dict()
median_ans_dict
# Out:
# {0.0: 3.0,
#  1.0: 10.0,
#  2.0: 16.0,
#  3.0: 25.0,
#  4.0: 37.0,
#  5.0: 50.0,
#  6.0: 68.0,
#  7.0: 90.0,
#  8.0: 120.0,
#  9.0: 142.0,
#  10.0: 169.0,
#  11.0: 229.0,
#  12.0: 206.5,
#  13.0: 267.0,
#  14.0: 316.0,
#  15.0: 368.0,
#  16.0: 376.0,
#  17.0: 454.0,
#  18.0: 516.0,
#  19.0: 505.5,
#  20.0: 527.0,
#  21.0: 604.0,
#  22.0: 746.0,
#  23.0: 794.0,
#  24.0: 1244.0,
#  25.0: 919.0,
#  26.0: 1520.0,
#  27.0: 1025.0,
#  28.0: 1251.0,
#  29.0: 1385.0,
#  30.0: 1243.5,
#  31.0: 861.0,
#  32.0: 1947.0,
#  33.0: 834.0,
#  34.0: 720.5,
#  35.0: 2681.0,
#  36.0: 4767.5,
#  37.0: 979.0,
#  38.0: 5634.5,
#  39.0: 5294.5,
#  40.0: 4297.0,
#  41.0: 3598.0,
#  42.0: 1460.0,
#  43.0: 3056.5,
#  44.0: 23360.5,
#  45.0: 760.0,
#  46.0: 11770.0,
#  47.0: 4848.5,
#  48.0: 2384.5,
#  49.0: 4798.0,
#  50.0: 44685.5,
#  51.0: 1805.0,
#  53.0: 84511.0,
#  54.0: 306.0,
#  55.0: 32958.0,
#  57.0: 6137.0,
#  58.0: 881.5,
#  59.0: 261157.0,
#  60.0: 5798.0,
#  61.0: 6863.0,
#  62.0: 2969.5,
# ...

# %%
train['median_wt_ans'] = train['Answers'].apply(lambda x: median_ans_dict[x])
train['mean_wt_ans'] = train['Answers'].apply(lambda x: mean_ans_dict[x])
train
# Out:
#             ID Tag  Reputation  Answers  Username     Views  Upvotes  \
# 0        52664   a      3942.0      2.0    155623    7855.0     42.0
# 1       327662   a     26046.0     12.0     21781   55801.0   1175.0
# 2       468453   c      1358.0      4.0     56177    8067.0     60.0
# 3        96996   a       264.0      3.0    168793   27064.0      9.0
# 4       131465   c      4271.0      4.0    112223   13986.0     83.0
# 5       345568   r       440.0      1.0     23866    5577.0      4.0
# 6       376865   c       147.0      1.0     10759   17184.0     17.0
# 7       467378   j      2269.0      2.0     54623     312.0      3.0
# 8       393640   j       111.0      2.0    172926   53738.0     79.0
# 9       130054   c      2749.0      1.0     10189     227.0      0.0
# 10      218471   c      1142.0      7.0     71822  141836.0    166.0
# 11      144119   p      2554.0      1.0    137817    8086.0     42.0
# 12      155955   s       591.0      4.0     36550   16102.0     19.0
# ...

# %%
test['median_wt_ans'] = test['Answers'].apply(lambda x: median_ans_dict[x] if x in median_ans_dict.keys() else None)
test['mean_wt_ans'] = test['Answers'].apply(lambda x: mean_ans_dict[x] if x in mean_ans_dict.keys() else None)
test
# Out:
#             ID Tag  Reputation  Answers  Username     Views      Upvotes  \
# 0       366953   a      5645.0      3.0     50652   33200.0   378.357995
# 1        71864   c     24511.0      6.0     37685    2730.0   295.293518
# 2       141692   i       927.0      1.0    135293   21167.0   138.077272
# 3       316833   i        21.0      6.0    166998   18528.0  -123.361623
# 4       440445   i      4475.0     10.0     53504   57240.0   650.079077
# 5         3514   c      3252.0      1.0    115109    2307.0  -247.272284
# 6       331420   x       859.0      1.0     88355    6507.0  -169.131508
# 7       406540   c       770.0      4.0     74489   57775.0   661.334806
# 8       227379   s      8727.0      2.0     37904    4459.0   -18.171851
# 9       331687   p       170.0      4.0    162810    4899.0  -440.542391
# 10       32784   p        58.0      2.0    156743    1251.0  -445.078561
# 11      470377   s       727.0      2.0      1960   27814.0   176.318951
# ...

# %%
test.loc[test['median_wt_ans'].isnull()]
# Out:
#            ID Tag  Reputation  Answers  Username      Views       Upvotes  \
# 41300   48890   a      3055.0     68.0    117951   871764.0  14583.777395
# 73521  112456   j     15130.0     73.0     79208  1511919.0  27399.217090
#
#        mean_wt_tag  median_wt_ans  mean_wt_ans
# 41300   316.460136            NaN          NaN
# 73521   540.364686            NaN          NaN

# %%
test.loc[test['median_wt_ans'].isnull(), 'median_wt_ans'] = test.loc[test['median_wt_ans'].isnull()]['Answers'].apply(lambda x: median_ans_dict[x-2] if x-2 in median_ans_dict.keys() else median_ans_dict[x+3])
test.loc[test['mean_wt_ans'].isnull(), 'mean_wt_ans'] = test.loc[test['mean_wt_ans'].isnull()]['Answers'].apply(lambda x: mean_ans_dict[x-2] if x-2 in mean_ans_dict.keys() else mean_ans_dict[x+3])
test.loc[test['median_wt_ans'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Tag, Reputation, Answers, Username, Views, Upvotes, mean_wt_tag, median_wt_ans, mean_wt_ans]
# Index: []

# %%
train['log_upvotes'] = np.log(train['Upvotes'] + 1)
train.corr()
# Out:
#                      ID  Reputation   Answers  Username     Views   Upvotes  \
# ID             1.000000    0.008546  0.017448  0.000628  0.017400  0.006328
# Reputation     0.008546    1.000000  0.066504 -0.041019  0.036455  0.266710
# Answers        0.017448    0.066504  1.000000 -0.012197  0.498642  0.202033
# Username       0.000628   -0.041019 -0.012197  1.000000  0.002306 -0.011970
# Views          0.017400    0.036455  0.498642  0.002306  1.000000  0.437336
# Upvotes        0.006328    0.266710  0.202033 -0.011970  0.437336  1.000000
# mean_wt_tag    0.022343    0.034407  0.099160  0.014632  0.116831  0.040157
# median_wt_ans  0.004006    0.016478  0.249475  0.000498  0.267952  0.211864
# mean_wt_ans    0.009227    0.043589  0.680277 -0.004935  0.465090  0.296987
# log_upvotes    0.029158    0.388262  0.450966 -0.064312  0.442350  0.253908
#
#                mean_wt_tag  median_wt_ans  mean_wt_ans  log_upvotes
# ...

# %%
ridgecv = RidgeCV(alphas=(0.0017, 0.00175, 0.0018), normalize=True)
ridgecv.fit(train[['Answers', 'Views', 'Reputation', 'mean_wt_tag']], train['Upvotes'])
ridgecv.alpha_
# Out:
# 0.0018

# %%
ridge = Ridge(alpha=0.0018, normalize= True)
ridge.fit(train[['Reputation', 'Answers', 'Views', 'mean_wt_tag']], train['log_upvotes'])
y_pred = ridge.predict(test[['Reputation', 'Answers', 'Views', 'mean_wt_tag']])
test['Upvotes'] = np.exp(y_pred) -1
ridge_ans_tag = test.sort_values('ID')
ridge_ans_tag
# Out:
#             ID Tag  Reputation  Answers  Username     Views        Upvotes  \
# 118045       7   h      2552.0     16.0    114390  284348.0     917.510826
# 74256        9   j      1240.0      2.0     59362    6587.0      23.123900
# 132030      12   p       560.0      6.0     44764   37074.0      43.202513
# 47484       13   j     16807.0      3.0     25037   17598.0      42.564572
# 20847       16   i       896.0      4.0    134342   16800.0      20.368424
# 140788      17   x     67157.0     10.0    100794   85709.0     404.680641
# 17680       22   c       103.0      1.0     35973     464.0      14.473815
# 28140       25   j       602.0      6.0     26545   26047.0      46.741028
# 55781       26   c       107.0      4.0     41953   13714.0      24.899354
# 96215       27   j      1117.0      3.0     98395   37627.0      32.834987
# 93870       33   p      1647.0      6.0     54659   13065.0      37.945822
# ...

# %%
# ridge_ans_tag[['ID', 'Upvotes']].to_csv('ridge_log_upvotes.csv')

# %%
train.columns
# Out:
# Index(['ID', 'Tag', 'Reputation', 'Answers', 'Username', 'Views', 'Upvotes',
#        'mean_wt_tag', 'median_wt_ans', 'mean_wt_ans', 'log_upvotes'],
#       dtype='object')

# %%
train.loc[train['Reputation'] == 0].shape
# Out:
# (6632, 11)

# %%
train.loc[train['Answers'] == 0].shape
# Out:
# (2082, 11)

# %%
train.loc[train['Views'] == 0].shape
# Out:
# (0, 11)

# %%
a = train.loc[train['Upvotes'] < 100000]
plt.scatter(a['Views'], a['Upvotes'])
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
param_grid = { 
            "n_estimators"      : [2,5, 10],
            "max_features"      : ["auto"],
            "min_samples_split" : [2, 4, 8],
            }

# %%
grid = GridSearchCV(rf, param_grid)
grid.fit(train[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']], train['Upvotes'])
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=4,
#            min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [1, 2, 5], 'max_features': ['auto'], 'min_samples_split': [4, 8]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print(grid.best_params_, grid.best_score_)
# Out:
# {'max_features': 'auto', 'min_samples_split': 4, 'n_estimators': 5} 0.832122550253

# %%
rf = RandomForestRegressor()
rf.fit(train[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']], train['Upvotes'])
y_pred = rf.predict(test[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']])
test['Upvotes'] = y_pred
rfr_ans_tag = test.sort_values('ID')
rfr_ans_tag
# Out:
#             ID Tag  Reputation  Answers  Username     Views       Upvotes  \
# 118045       7   h      2552.0     16.0    114390  284348.0    863.026667
# 74256        9   j      1240.0      2.0     59362    6587.0     23.333333
# 132030      12   p       560.0      6.0     44764   37074.0     73.798571
# 47484       13   j     16807.0      3.0     25037   17598.0    385.840000
# 20847       16   i       896.0      4.0    134342   16800.0     28.315238
# 140788      17   x     67157.0     10.0    100794   85709.0   5364.166667
# 17680       22   c       103.0      1.0     35973     464.0     74.175000
# 28140       25   j       602.0      6.0     26545   26047.0     28.400000
# 55781       26   c       107.0      4.0     41953   13714.0     22.066667
# 96215       27   j      1117.0      3.0     98395   37627.0     67.000000
# 93870       33   p      1647.0      6.0     54659   13065.0     35.335714
# 391         43   i      4988.0      2.0     30272    2446.0     79.000000
# ...

# %%
rfr_ans_tag[['ID', 'Upvotes']].to_csv('rfr_med_ans_tag.csv')

# %%
param_grid = { 
            "n_estimators"      : [100],
            "max_features"      : ["auto"],
            "min_samples_split" : [4],
            'learning_rate': [0.1,0.05]
            }

# %%
grad = GradientBoostingRegressor()
grid = GridSearchCV(grad, param_grid)
grid.fit(train[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']], train['Upvotes'])
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [100], 'max_features': ['auto'], 'min_samples_split': [4], 'learning_rate': [0.1, 0.05]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print(grid.best_params_, grid.best_score_)
# Out:
# {'learning_rate': 0.1, 'max_features': 'auto', 'min_samples_split': 4, 'n_estimators': 100} 0.865513836174

# %%
grad = GradientBoostingRegressor(max_features='auto', min_samples_split=4, n_estimators=1000)
grad.fit(train[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']], train['Upvotes'])
y_pred = grad.predict(test[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']])
test['Upvotes'] = y_pred
grad_ans_tag = test.sort_values('ID')
grad_ans_tag
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-89bd7d678b98> in <module>()
#       1 grad = GradientBoostingRegressor(max_features='auto', min_samples_split=4, n_estimators=1000)
# ----> 2 grad.fit(train[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']], train['Upvotes'])
#       3 y_pred = grad.predict(test[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']])
#       4 test['Upvotes'] = y_pred
#       5 grad_ans_tag = test.sort_values('ID')
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#    1032         # fit the boosting stages
#    1033         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1034                                     begin_at_stage, monitor, X_idx_sorted)
# ...

# %%
grad_ans_tag.loc[grad_ans_tag['Upvotes'] < 0]

# %%
grad_ans_tag['Upvotes'] = grad_ans_tag['Upvotes'].apply(lambda x: 0 if x < 0 else x)

# %%
grad_ans_tag[['ID', 'Upvotes']].to_csv('grad_med_ans_tag.csv')

# %%
param_grid = { 
            "n_estimators"      : [100, 500],
            }

# %%
ada = AdaBoostRegressor()
grid = GridSearchCV(ada, param_grid)
grid.fit(train[['Reputation', 'Answers', 'Views', 'mean_wt_tag', 'mean_wt_ans', 'median_wt_ans']], train['Upvotes'])
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#          n_estimators=50, random_state=None),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [100, 500]}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score='warn', scoring=None, verbose=0)

# %%
print(grid.best_params_, grid.best_score_)
# Out:
# {'n_estimators': 100} -1.56508316239

# %%
# Out:
#             ID Tag  Reputation  Answers  Username     Views       Upvotes  \
# 118045       7   h      2552.0     16.0    114390  284348.0  13147.333617
# 74256        9   j      1240.0      2.0     59362    6587.0   6565.002044
# 132030      12   p       560.0      6.0     44764   37074.0  10213.796196
# 47484       13   j     16807.0      3.0     25037   17598.0   9834.772659
# 20847       16   i       896.0      4.0    134342   16800.0   6565.002044
# 140788      17   x     67157.0     10.0    100794   85709.0  47568.847394
# 17680       22   c       103.0      1.0     35973     464.0   6565.002044
# 28140       25   j       602.0      6.0     26545   26047.0   7407.486831
# 55781       26   c       107.0      4.0     41953   13714.0   6565.002044
# 96215       27   j      1117.0      3.0     98395   37627.0  10213.796196
# 93870       33   p      1647.0      6.0     54659   13065.0   6565.002044
# 391         43   i      4988.0      2.0     30272    2446.0   6565.002044
# ...
